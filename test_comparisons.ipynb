# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pywt
import pandas as pd
import utils as u
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Visually classify mode changes

# %%
profs = np.loadtxt('J0332_profs.txt')
mjd = np.loadtxt('J0332_MJD.txt')

u.gridplot(profs, 4, hist=False)

# %%
abnormal_ind = np.array([9, 16, 17, 18, 22, 31, 32, 35, 38, 40, 52, 56])
abnormal = profs[abnormal_ind]
abn_mjd = mjd[abnormal_ind]

normal = [profile for profile in profs if profile not in abnormal]
nor_mjd = [date for date in mjd if date not in abn_mjd]

# %% [markdown]
# Proportion in literature is around 82% normal, 18% abnormal

# %%
#proportions are similar
len(normal)/len(profs), len(abnormal) / len(profs)
# Out:
# (0.8064516129032258, 0.1935483870967742)

# %% [markdown]
# ### Save (visually classified) normal and abnormal MJDs as arrays to compare in KS test notebook

# %%
np.savetxt('./classified_mjd/J0332_norm_mjd_visual.txt', nor_mjd)
np.savetxt('./classified_mjd/J0332_abnnorm_mjd_visual.txt', abn_mjd)
