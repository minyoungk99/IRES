# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('/Users/MYK/Desktop/IRES/scripts')

import utils as u
import numpy as np
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
mjd = np.loadtxt('../J0332_MJD.txt')
profs = np.loadtxt('../J0332_profs.txt')

# %% [markdown]
# ### MJDs classified by wavelet power spectra testing of differences, only consider contours with holes as significant

# %%
#repeating MJDs, so use indices bc that is unique, second 58629 is significant, first one is not
abn_ind = [9, 17, 22, 23, 27, 29, 31, 32, 45, 52, 56]
abn_mjd = [mjd[ind] for ind in abn_ind]

norm_mjd = []
for ind in range(len(mjd)):
    if ind not in abn_ind:
        norm_mjd.append(mjd[ind])

# %%
np.savetxt('../classified_mjd/J0332_norm_mjd_wavelet_diff.txt', norm_mjd)
np.savetxt('../classified_mjd/J0332_abnorm_mjd_wavelet_diff.txt', abn_mjd)

# %%
abn_profs = [profs[i] for i in abn_ind]

fig = plt.figure(figsize=(4, 4))
plt.plot(profs[0])
plt.title("Reference Profile")
plt.show()
u.gridplot(abn_profs, 4, hist=False, figsize=(15, 10))
