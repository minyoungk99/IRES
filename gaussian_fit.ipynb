# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import numpy as np
import scipy.integrate as si
import scipy.special as ss
import scipy.stats as st
from scipy.fftpack import fft, ifft
import utils as u
import fake_profile as fp
import csv
from astropy.modeling import models, fitting
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
a = [2,7,4]
mu = [20,50,80]
sd = [2,3,3]

p1 = fp.profile(a,mu,sd); p1.construct_profile(noise=True)

# %%
plt.plot(p1.domain,p1.profile)
plt.show()

# %%
amp = [1,1,1]
mean = [19, 45, 83]
stddev = [1,1,1]
g = u.gaussian_fit(x, p1.profile, amp, mean, stddev)
# Out:
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]

# %%
plt.plot(p1.domain, p1.profile,'b',label='data')
plt.plot(p1.domain, g(x),'r',label='fit')
plt.legend()
plt.show()
g.parameters
# Out:
# array([  4.67486747e-03,   9.20842650e+00,   5.36043128e+00,
#          3.90541160e-01,   2.00357251e+01,   1.96635711e+00,
#          9.24109370e-01,   5.00057745e+01,   2.98425202e+00,
#          5.34183354e-01,   8.01573487e+01,   2.98666934e+00])
